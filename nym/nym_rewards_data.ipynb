# %%
import requests
import time
import pandas as pd
import os
from datetime import datetime
from datetime import timedelta
from datetime import date
import numpy as np

# %%
def convert_blocktime(blocktime, delta = 6):
    if blocktime is None:
        return None
    else:
        timestr = blocktime.replace('T',' ').replace('Z','')
        return datetime.strptime(timestr[:-delta], "%Y-%m-%d %H:%M:%S")

# %%
def get_mixnodes(used_api):
    
    if used_api=='nymtech_api':
        request_str = 'https://validator.nymtech.net/api/v1/mixnodes/'
    elif used_api=='api_guru':
        request_str = 'https://mixnet.api.explorers.guru/api/mixnodes'
    
    print(request_str)
    return requests.get(request_str).json()

# %%
def get_mixnode_balance(mix_id):
    request_str='https://mixnet.api.explorers.guru/api/accounts/{mix_id}/balance'.format(mix_id=mix_id)
    print(request_str)
    return requests.get(request_str).json()

def get_account_pledge(account_id):
    request_str='https://mixnet.api.explorers.guru/api/accounts/{account_id}/bondings'.format(account_id=account_id)
    print(request_str)
    return requests.get(request_str).json()

# %%
def get_network_rewards_history(min_epoch,max_epoch):
    dct_out={'epoch':[],
            'rewards':[],
            'apy':[]}
    for i in range(min_epoch,max_epoch):
        request_str = 'https://mixnet.api.explorers.guru/api/mixnodes/apy/{epoch}'.format(epoch=str(i))
        print(request_str)
        dct_rewards = requests.get(request_str).json()
        if dct_rewards:
            dct_out['epoch'].append(i)
            if 'rewards1h' in dct_rewards.keys():
                dct_out['rewards'].append(dct_rewards['rewards1h'])
            else:
                dct_out['rewards'].append(0)
            if 'apy' in dct_rewards.keys():
                dct_out['apy'].append(dct_rewards['apy'])
            else:
                dct_out['apy'].append(0)
        else:
            print('no dct for '+str(i))
    return pd.DataFrame.from_dict(dct_out)

# %%
def get_mixnode_reward_estimate(mix_id):
    request_str = 'https://mixnet.api.explorers.guru/api/mixnodes/{mix_id}/estimated_reward'.format(mix_id=mix_id)
    print(request_str)
    return requests.get(request_str).json()

# %%
def get_mixnode_stats(mix_ip_address):
    dct_out={'packets_received_since_startup':None,
    'packets_sent_since_startup':None,
    'packets_explicitly_dropped_since_startup':None}
        
    request_str = 'https://{mix_ip_address}:8000/stats'.format(mix_ip_address=mix_ip_address)
    print(request_str)

    try:
        result = requests.get(request_str)
    except requests.exceptions.RequestException as e:  
        print(e)
        result = None
    except requests.exceptions.HTTPError as errh:
        print ("Http Error:",errh)
        result = None

    print(result)
    if result:
        return result.json()
    else:
        return dct_out

# %%
def get_uptime(mix_id):
    request_str = 'https://mixnet.api.explorers.guru/api/mixnodes/{mix_id}/uptime'.format(mix_id=mix_id)
    print(request_str)
    return requests.get(request_str).json()
    
def get_block_date(blockheight,**kwargs):
    blockcount = kwargs.get('blockcount',1)
    request_str = 'https://mixnet.api.explorers.guru/api/blocks?count={blockcount}&height={blockheight}'.format(blockcount=blockcount,blockheight=blockheight)
    print(request_str)
    return requests.get(request_str).json()

# %%
def get_price_history():
    request_str='https://mixnet.api.explorers.guru/api/market/history'
    print(request_str)
    dct_prices = requests.get(request_str).json()
    if dct_prices:
        df_prices = pd.DataFrame.from_dict(dct_prices)
        df_prices['datestr']=[convert_blocktime(df_prices.iloc[i].timestamp, delta=4) for i in range(0,len(df_prices))]
        return df_prices.sort_values(by='datestr',ascending=False)
    else:
        print('error pulling price history')
        return pd.DataFrame.from_dict({})

# %%
def get_price_data():
    dct_out={}
    request_str='https://mixnet.api.explorers.guru/api/market/price'
    print(request_str)
    dct_prices = requests.get(request_str).json()
    if dct_prices:
        cnt = 0
        for k in dct_prices.keys():
            if cnt==0:
                dct_out[k]=[]
            
            dct_out[k].append(dct_prices[k])
        
        df_prices = pd.DataFrame.from_dict(dct_out)
        df_prices['datestr']=[convert_blocktime(df_prices.iloc[i].timestamp, delta=4) for i in range(0,len(df_prices))]
        return df_prices
    else:
        print('error pulling price history')
        return pd.DataFrame.from_dict({})
    

def read_mixnodes(**kwargs):
    
    conversion_factor = kwargs.get('conversion_factor',np.power(10,6))
    start_node = kwargs.get('start_node',0)
    node_data = get_mixnodes('nymtech_api')
    df_node_data_2 = pd.DataFrame.from_dict(get_mixnodes('api_guru'))
    


    dct_out=  {} 
    for i in range(start_node,len(node_data)):
        output_balance = get_mixnode_balance(node_data[i]['bond_information']['owner'])
        
        mix_id=node_data[i]['bond_information']['mix_id']
        mix_ip_address=node_data[i]['bond_information']['mix_node']['host']
        
        estimates = get_mixnode_reward_estimate(mix_id)
        uptime= get_uptime(mix_id)
        stats = get_mixnode_stats(mix_ip_address)

        if i==0:
            dct_out['id']=[]
            dct_out['owner']=[]  
            dct_out['rank']=[] 
            dct_out['status']=[] 
            dct_out['verify']=[] 
            dct_out['warning']=[] 
            dct_out['warning_description']=[] 
            dct_out['saturation']=[]
            dct_out['current_bond']=[]
            dct_out['last_touched']=[]
            dct_out['stake_share']=[]
            dct_out['original_pledge']=[]
            dct_out['layer']=[]
            dct_out['mix_node_ip']=[]
            dct_out['mix_node_sphinx_key']=[]
            dct_out['mix_node_identity_key']=[]
            dct_out['mix_node_version']=[]
            dct_out['proxy']=[]
            dct_out['bonding_height']=[]
            dct_out['is_unbonding']=[]
            dct_out['profit_margin']=[]
            dct_out['cost_hour']=[]
            dct_out['delegate_stake']=[]
            dct_out['reward_total']=[]
            dct_out['last_rewarded_epoch']=[]
            dct_out['unique_delegations']=[]
            dct_out['apy']=[]
            dct_out['total_node_reward_estimate']=[]
            dct_out['operator_estimate']=[]
            dct_out['delegates_estimate']=[]
            dct_out['uptime_most_recent']=[]
            dct_out['uptime_last_hour']=[]
            dct_out['uptime_last_day']=[]
            dct_out['packets_received_since_startup']=[]
            dct_out['packets_sent_since_startup']=[]
            dct_out['packets_explicitly_dropped_since_startup']=[]

            for k in output_balance.keys():
                dct_out[k]=[]

        dct_out['id'].append(mix_id)
        dct_out['owner'].append(df_node_data_2[df_node_data_2['mixId']==mix_id]['address'].iloc[0])
        dct_out['rank'].append(df_node_data_2[df_node_data_2['mixId']==mix_id]['rank'].iloc[0]) 
        dct_out['status'].append(df_node_data_2[df_node_data_2['mixId']==mix_id]['status'].iloc[0])
        dct_out['saturation'].append(df_node_data_2[df_node_data_2['mixId']==mix_id]['saturationPercent'].iloc[0])    
        dct_out['current_bond'].append(df_node_data_2[df_node_data_2['mixId']==mix_id]['bond'].iloc[0]/conversion_factor)    
        dct_out['original_pledge'].append(float(node_data[i]['bond_information']['original_pledge']['amount'])/conversion_factor)
        dct_out['delegate_stake'].append(float(node_data[i]['rewarding_details']['delegates'])/conversion_factor)
        dct_out['last_touched'].append(convert_blocktime(df_node_data_2[df_node_data_2['mixId']==mix_id]['touched'].iloc[0],delta=4))    
        dct_out['stake_share'].append(df_node_data_2[df_node_data_2['mixId']==mix_id]['totalStakePercent'].iloc[0])
        dct_out['apy'].append(df_node_data_2[df_node_data_2['mixId']==mix_id]['apy'].iloc[0])
        dct_out['total_node_reward_estimate'].append(float(estimates['total_node_reward'])/conversion_factor)
        dct_out['operator_estimate'].append(float(estimates['operator'])/conversion_factor)
        dct_out['delegates_estimate'].append(float(estimates['delegates'])/conversion_factor)
        dct_out['profit_margin'].append(float(node_data[i]['rewarding_details']['cost_params']['profit_margin_percent']))
        dct_out['cost_hour'].append(float(node_data[i]['rewarding_details']['cost_params']['interval_operating_cost']['amount'])/conversion_factor/24/31) #check if they cahnge the month-days
        dct_out['reward_total'].append(float(node_data[i]['rewarding_details']['total_unit_reward'])/conversion_factor)
        dct_out['last_rewarded_epoch'].append(int(node_data[i]['rewarding_details']['last_rewarded_epoch']))
        dct_out['unique_delegations'].append(int(node_data[i]['rewarding_details']['unique_delegations']))
        dct_out['uptime_most_recent'].append(uptime['most_recent'])
        dct_out['uptime_last_hour'].append(uptime['last_hour'])
        dct_out['uptime_last_day'].append(uptime['last_day'])
        dct_out['packets_received_since_startup'].append(stats['packets_received_since_startup'])
        dct_out['packets_sent_since_startup'].append(stats['packets_sent_since_startup'])
        dct_out['packets_explicitly_dropped_since_startup'].append(stats['packets_explicitly_dropped_since_startup'])
        dct_out['layer'].append(int(node_data[i]['bond_information']['layer']))
        dct_out['mix_node_ip'].append(mix_ip_address)
        dct_out['mix_node_sphinx_key'].append(node_data[i]['bond_information']['mix_node']['sphinx_key'])
        dct_out['mix_node_identity_key'].append(node_data[i]['bond_information']['mix_node']['identity_key'])
        dct_out['mix_node_version'].append(node_data[i]['bond_information']['mix_node']['version'])
        dct_out['proxy'].append(node_data[i]['bond_information']['proxy'])
        dct_out['bonding_height'].append(int(node_data[i]['bond_information']['bonding_height']))
        dct_out['is_unbonding'].append(int(node_data[i]['bond_information']['is_unbonding']))
        dct_out['verify'].append(df_node_data_2[df_node_data_2['mixId']==mix_id]['verify'].iloc[0])
        dct_out['warning'].append(df_node_data_2[df_node_data_2['mixId']==mix_id]['warning'].iloc[0])
        dct_out['warning_description'].append(df_node_data_2[df_node_data_2['mixId']==mix_id]['warningDescription'].iloc[0])    
        
        for k in output_balance.keys():
            dct_out[k].append(float(output_balance[k]['amount'])/conversion_factor)
        

    return pd.DataFrame.from_dict(dct_out)

# %%
#network rewards per epoch, mapping to dates via relationship 1 epoch ~ 1h
df_reward_history = get_network_rewards_history(1,4000)
# Out:
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3860
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3861
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3862
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3863
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3864
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3865
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3866
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3867
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3868
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3869
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3870
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3871
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3872
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3873
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3874
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3875
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3876
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3877
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3878
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3879
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3880
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3881
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3882
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3883
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3884
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3885
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3886
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3887
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3888
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3889
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3890
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3891
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3892
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3893
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3894
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3895
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3896
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3897
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3898
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3899
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3900
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3901
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3902
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3903
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3904
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3905
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3906
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3907
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3908
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3909
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3910
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3911
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3912
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3913
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3914
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3915
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3916
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3917
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3918
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3919
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3920
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3921
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3922
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3923
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3924
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3925
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3926
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3927
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3928
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3929
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3930
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3931
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3932
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3933
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3934
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3935
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3936
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3937
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3938
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3939
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3940
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3941
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3942
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3943
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3944
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3945
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3946
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3947
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3948
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3949
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3950
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3951
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3952
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3953
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3954
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3955
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3956
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3957
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3958
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3959
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3960
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3961
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3962
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3963
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3964
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3965
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3966
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3967
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3968
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3969
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3970
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3971
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3972
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3973
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3974
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3975
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3976
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3977
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3978
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3979
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3980
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3981
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3982
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3983
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3984
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3985
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3986
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3987
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3988
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3989
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3990
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3991
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3992
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3993
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3994
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3995
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3996
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3997
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3998
# https://mixnet.api.explorers.guru/api/mixnodes/apy/3999

# %%
#price data from coingecko
df_prices = pd.read_csv('nym-usd-max.csv')
df_prices['datestr']=[convert_blocktime(df_prices.snapped_at.iloc[i], delta=4) for i in range(0, len(df_prices))]
df_prices['dateday']=[date(df_prices.datestr.iloc[i].year, df_prices.datestr.iloc[i].month, df_prices.datestr.iloc[i].day)for i in range(0, len(df_prices))]
df_reward_history['datestr']=[datetime.strptime('2023-01-13 12:00:00','%Y-%m-%d %H:%M:%S')-(691-df_reward_history.epoch.iloc[i])*timedelta(hours=1) for i in range(0, len(df_reward_history))]
df_reward_history['dateday']=[date(df_reward_history.datestr.iloc[i].year, df_reward_history.datestr.iloc[i].month, df_reward_history.datestr.iloc[i].day)for i in range(0, len(df_reward_history))]
df_reward_history['year_month']=[str(df_reward_history.datestr.iloc[i].year) + "-" + str(df_reward_history.datestr.iloc[i].month) for i in range(0, len(df_reward_history))]
df_reward_history_month =df_reward_history.groupby('year_month').agg(
 num_epochs = ('datestr','count'),
    sum_rewards=('rewards','sum')   
).reset_index()
df_reward_history_days = df_reward_history.groupby('dateday').agg(
    num_repochs = ('datestr','count'),
    sum_rewards=('rewards','sum')
).reset_index().merge(df_prices,how='left',left_on='dateday',right_on='dateday')
df_reward_history_days['rewards_usd']=df_reward_history_days.sum_rewards*df_reward_history_days.price

# %%
#Nodecount: get all current mixnodes and then get date of first pledge
dct_mixnodes = get_mixnodes('api_guru')
df_mixnodes=pd.DataFrame.from_dict(dct_mixnodes)

# %%
df_mixnodes['first_pledge']=np.nan
for i in range(0,len(df_mixnodes)):

    a = df_mixnodes.iloc[i].address
    dct_out=get_account_pledge(a)
    if len(dct_out)>0:
        blockdate = get_block_date(dct_out[0]['block'])
        delta = len(blockdate[0]['time'])-20
        blocktime = convert_blocktime(blockdate[0]['time'],delta=delta)
        df_mixnodes.loc[df_mixnodes.address==a,'first_pledge'] = blocktime
# Out:
# https://mixnet.api.explorers.guru/api/accounts/n12fxasranak2spt8cge0erp6293c7l4wzpapy22/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=
bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=2116149
# https://mixnet.api.explorers.guru/api/accounts/n1z2sm5099vuul6ujueths3rc4skx7c69r9zq6zx/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=7041123
# https://mixnet.api.explorers.guru/api/accounts/n1z6uq7q2huh8hc0kjuvnstkdc7rgrddhrg7z3ts/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=2637860
# https://mixnet.api.explorers.guru/api/accounts/n1z85hjs3uljmwwykfmt0u4et8pe8c5fgxtptnew/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=3416558
# https://mixnet.api.explorers.guru/api/accounts/n1z9aemj9ehhvcwdrcrp6j9xh4h7f7serfm70gt5/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=5502965
# https://mixnet.api.explorers.guru/api/accounts/n1zjcrxtvvc3y5jqeuvgxl7plxqlhc62yz3vxcjn/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=4274628
# https://mixnet.api.explorers.guru/api/accounts/n1zl9fn9pwd960gpx0erh5deq70ufwmn0nqdrnwf/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=5225806
# https://mixnet.api.explorers.guru/api/accounts/n1zlqphry7zxkatsysvkp8qxfchhyxxekvfh35g9/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=4360257
# https://mixnet.api.explorers.guru/api/accounts/n1zmeq0a3jvklsnjdt894pdr806r4jmrcgft9l3g/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=3040081
# https://mixnet.api.explorers.guru/api/accounts/n1zp62ust722r3wuxmf2n95m4mcumkwwmskf56hr/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=4655590
# https://mixnet.api.explorers.guru/api/accounts/n1zpjkp79seu5drhkr62yeyvw0kc7f49se0scd26/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=4336632
# https://mixnet.api.explorers.guru/api/accounts/n1zqd0wxzdq67qww09y286eg9awgrt3sefzt6c58/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=5591412
# https://mixnet.api.explorers.guru/api/accounts/n1zqkssacvr0ecyh2cysvuqat792k9vqnte0lq6r/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=4803909
# https://mixnet.api.explorers.guru/api/accounts/n1ztsvusgzsr2ztrwrwekaq9mmv0fpd2g5hds5ja/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=6972160
# https://mixnet.api.explorers.guru/api/accounts/n1zu6npsgsylsykl6tr4azrupr3mh6epzgr36f2x/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=1627635
# https://mixnet.api.explorers.guru/api/accounts/n1zu9vnmww9agrw3k4l9mcaqdtpu9k3tert9ac64/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=5428128
# https://mixnet.api.explorers.guru/api/accounts/n1zuk8f53xc5sv03n9kac0fmtmnwrsda6yahvngu/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=3370301
# https://mixnet.api.explorers.guru/api/accounts/n1zxdgwyf6szufzn8n8xjh75z8639y0z80gjx8dh/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=4298431
# https://mixnet.api.explorers.guru/api/accounts/n1zytu0jz55ww2299msdz7qr8ucd6n4n4swup5q2/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=3882928
# https://mixnet.api.explorers.guru/api/accounts/n1zyvezkhj3wxaknv97usjrphh4kntuw2m7vlet7/bondings
# https://mixnet.api.explorers.guru/api/blocks?count=1&height=4094117

# %%
df_mixnodes['first_pledge_month'] = [str(df_mixnodes.iloc[i].first_pledge)[0:7] for i in range(0,len(df_mixnodes))]

# %%
df_node_count = df_mixnodes.groupby('first_pledge_month').agg({'id':'nunique'}).reset_index()
df_node_count['cs_count'] = df_node_count.id.cumsum()

# %%
#node level details - current data
conversion_factor = np.power(10,6) #decimals of NYM
df_nodes = read_mixnodes(conversion_factor=conversion_factor)
# Out:
# https://validator.nymtech.net/api/v1/mixnodes/
# https://mixnet.api.explorers.guru/api/mixnodes
# https://mixnet.api.explorers.guru/api/accounts/n1cg6lgel27zmq8yutxgnu2tdzx3hf0m8uemfpwp/balance
# https://mixnet.api.explorers.guru/api/mixnodes/1/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/1/uptime
# https://116.203.115.86:8000/stats
# HTTPSConnectionPool(host='116.203.115.86', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1vfdtzh9vzaaxxv9n9w4ywdzle9m2pejhx0d5r7/balance
# https://mixnet.api.explorers.guru/api/mixnodes/2/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/2/uptime
# https://95.179.226.75:8000/stats
# HTTPSConnectionPool(host='95.179.226.75', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1v7nrjw6pnkrdxmmuk7pjtxrzrxrtztgh33pszu/balance
# https://mixnet.api.explorers.guru/api/mixnodes/5/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/5/uptime
# https://185.229.90.217:8000/stats
# HTTPSConnectionPool(host='185.229.90.217', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1kal4zg6d4xe8a9uygz4vh3ngyqgpjud53m0n9w/balance
# https://mixnet.api.explorers.guru/api/mixnodes/6/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/6/uptime
# https://139.162.60.229:8000/stats
# HTTPSConnectionPool(host='139.162.60.229', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1hn0fkhequgwdxw3d600jhax76j07kqdxklvcwn/balance
# https://mixnet.api.explorers.guru/api/mixnodes/8/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/8/uptime
# https://216.238.77.232:8000/stats
# HTTPSConnectionPool(host='216.238.77.232', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1tp79kkpyxtda362dq82epcl2p4ha0fly8eett8/balance
# https://mixnet.api.explorers.guru/api/mixnodes/9/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/9/uptime
# https://51.195.255.51:8000/stats
# HTTPSConnectionPool(host='51.195.255.51', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1jpkhjcrpqlvtzfkm7rn0rwuszcq559nay6duma/balance
# https://mixnet.api.explorers.guru/api/mixnodes/11/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/11/uptime
# https://185.8.62.115:8000/stats
# HTTPSConnectionPool(host='185.8.62.115', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1yv7smmmzsrqx88gze33sq6a02tn5u6ge808quz/balance
# https://mixnet.api.explorers.guru/api/mixnodes/14/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/14/uptime
# https://mixnode.nymers.com:8000/stats
# HTTPSConnectionPool(host='mixnode.nymers.com', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1huzvks30y0zvcvd68hl5mglaqnmnue5xkr9n72/balance
# https://mixnet.api.explorers.guru/api/mixnodes/15/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/15/uptime
# https://23.88.114.204:8000/stats
# HTTPSConnectionPool(host='23.88.114.204', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1av9397rz3k4f4z2k7y55udwsal5vwy7j5m7zm0/balance
# https://mixnet.api.explorers.guru/api/mixnodes/17/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/17/uptime
# https://5.161.114.178:8000/stats
# HTTPSConnectionPool(host='5.161.114.178', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1jsscc8x7qqs4aurrlheex62f8namxwsft3jmcx/balance
# https://mixnet.api.explorers.guru/api/mixnodes/21/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/21/uptime
# https://65.109.1.171:8000/stats
# HTTPSConnectionPool(host='65.109.1.171', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1l72yrntzu29nxrvvgarvwhnc2gwxu8yrazld78/balance
# https://mixnet.api.explorers.guru/api/mixnodes/23/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/23/uptime
# https://94.130.105.180:8000/stats
# HTTPSConnectionPool(host='94.130.105.180', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1rsmg3pkkfs29rafuxvw79ylmaj4czc22u7m0uf/balance
# https://mixnet.api.explorers.guru/api/mixnodes/26/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/26/uptime
# https://135.181.139.72:8000/stats
# HTTPSConnectionPool(host='135.181.139.72', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1ga39h8aw2l4d8aaalr5u2mewnqwa235nte9q32/balance
# https://mixnet.api.explorers.guru/api/mixnodes/29/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/29/uptime
# https://193.43.146.207:8000/stats
# HTTPSConnectionPool(host='193.43.146.207', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1xtfjvcz2umqd9tlc0qcl8zk9shwlvlg0nzzvkc/balance
# https://mixnet.api.explorers.guru/api/mixnodes/30/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/30/uptime
# https://65.108.52.71:8000/stats
# HTTPSConnectionPool(host='65.108.52.71', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1yy9sf2n90az2wthl34pg6sqkpwdj7jatxztapk/balance
# https://mixnet.api.explorers.guru/api/mixnodes/31/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/31/uptime
# https://118.238.220.142:8000/stats
# HTTPSConnectionPool(host='118.238.220.142', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1atf58txmdsqgcjhehla742u4w55gtuk02tx0qg/balance
# https://mixnet.api.explorers.guru/api/mixnodes/32/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/32/uptime
# https://65.108.104.113:8000/stats
# HTTPSConnectionPool(host='65.108.104.113', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1ws7pd24ak8g6decwncu43z6yzuhkfycwhre7qy/balance
# https://mixnet.api.explorers.guru/api/mixnodes/33/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/33/uptime
# https://82.216.163.131:8000/stats
# HTTPSConnectionPool(host='82.216.163.131', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1kl28zjn08uxa5c8mascm649v5g0wm9ve5r996x/balance
# https://mixnet.api.explorers.guru/api/mixnodes/36/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/36/uptime
# https://65.21.247.54:8000/stats
# HTTPSConnectionPool(host='65.21.247.54', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n10jg5eydhwqkkthmasrvhy40qhgv97zsltf0wca/balance
# https://mixnet.api.explorers.guru/api/mixnodes/37/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/37/uptime
# https://149.102.129.77:8000/stats
# HTTPSConnectionPool(host='149.102.129.77', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1hmul8zcrv794kjfh29tmxfc6tezcs63q82fhkn/balance
# https://mixnet.api.explorers.guru/api/mixnodes/38/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/38/uptime
# https://65.108.243.67:8000/stats
# HTTPSConnectionPool(host='65.108.243.67', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1x8xfaf4u6wxjq075htge665f37fedw8w6xdcxy/balance
# https://mixnet.api.explorers.guru/api/mixnodes/39/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/39/uptime
# https://162.55.174.117:8000/stats
# HTTPSConnectionPool(host='162.55.174.117', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n18r4s6a3pysr63lc002sqs7jhgrxze66nlz5sy7/balance
# https://mixnet.api.explorers.guru/api/mixnodes/40/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/40/uptime
# https://nym.sergo.dev:8000/stats
# HTTPSConnectionPool(host='nym.sergo.dev', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1t29kg76d4xalxa3xhdxehkk934r0la7qxllt8h/balance
# https://mixnet.api.explorers.guru/api/mixnodes/42/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/42/uptime
# https://161.97.71.166:8000/stats
# HTTPSConnectionPool(host='161.97.71.166', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1kq5fsztn9lsfm63whsvd5wgn8xwwp6ktm877xr/balance
# https://mixnet.api.explorers.guru/api/mixnodes/45/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/45/uptime
# https://149.28.214.159:8000/stats
# HTTPSConnectionPool(host='149.28.214.159', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1q85lscptz860j3dx92f8phaeaw08j2l5dt7adq/balance
# https://mixnet.api.explorers.guru/api/mixnodes/47/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/47/uptime
# https://88.201.196.152:8000/stats
# HTTPSConnectionPool(host='88.201.196.152', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1zmeq0a3jvklsnjdt894pdr806r4jmrcgft9l3g/balance
# https://mixnet.api.explorers.guru/api/mixnodes/52/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/52/uptime
# https://172.81.182.18:8000/stats
# HTTPSConnectionPool(host='172.81.182.18', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n137an7l7ww0r0scc9rn9hhwvwqk4efjt5xyah09/balance
# https://mixnet.api.explorers.guru/api/mixnodes/54/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/54/uptime
# https://65.21.6.230:8000/stats
# HTTPSConnectionPool(host='65.21.6.230', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1wz5e40mj83tahfyfkd40782kmnf2dzp3rmlu0n/balance
# https://mixnet.api.explorers.guru/api/mixnodes/55/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/55/uptime
# https://81.30.157.41:8000/stats
# HTTPSConnectionPool(host='81.30.157.41', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n13a3kl5kqu98e48z7q76sw8dvxjfucke0gk62r5/balance
# https://mixnet.api.explorers.guru/api/mixnodes/56/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/56/uptime
# https://135.181.114.98:8000/stats
# HTTPSConnectionPool(host='135.181.114.98', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n10cq36vecvefu905epmmwu5626kfwe0742mx98g/balance
# https://mixnet.api.explorers.guru/api/mixnodes/57/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/57/uptime
# https://204.15.76.157:8000/stats
# HTTPSConnectionPool(host='204.15.76.157', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1kkf3fcg7yg5gpeuzn0r2376e4m2etux85mle3w/balance
# https://mixnet.api.explorers.guru/api/mixnodes/59/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/59/uptime
# https://5.161.92.237:8000/stats
# HTTPSConnectionPool(host='5.161.92.237', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1rk87gfxgx95praexyjnewgv08q4p4muav565a9/balance
# https://mixnet.api.explorers.guru/api/mixnodes/60/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/60/uptime
# https://65.109.15.194:8000/stats
# HTTPSConnectionPool(host='65.109.15.194', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n16pjtrpppe8lfgrrnd4rnyx53pfej4ettgywqez/balance
# https://mixnet.api.explorers.guru/api/mixnodes/61/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/61/uptime
# https://135.181.250.81:8000/stats
# HTTPSConnectionPool(host='135.181.250.81', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1a3n3c2ehfcnszj7zgjugyl5j2et20ryj3ckczy/balance
# https://mixnet.api.explorers.guru/api/mixnodes/64/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/64/uptime
# https://77.91.101.170:8000/stats
# HTTPSConnectionPool(host='77.91.101.170', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n19dxfmu6kpzk89zjgdzzv3mvscsr99wpp2mpj26/balance
# https://mixnet.api.explorers.guru/api/mixnodes/66/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/66/uptime
# https://192.151.146.250:8000/stats
# HTTPSConnectionPool(host='192.151.146.250', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1hstgvwfttcg005rqphsh49yunvzuz0hzqeddzz/balance
# https://mixnet.api.explorers.guru/api/mixnodes/67/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/67/uptime
# https://5.161.81.152:8000/stats
# HTTPSConnectionPool(host='5.161.81.152', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1prag5au2x6h5cnls2vl5zl6ad02vhvza32ekpe/balance
# https://mixnet.api.explorers.guru/api/mixnodes/69/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/69/uptime
# https://5.161.114.34:8000/stats
# HTTPSConnectionPool(host='5.161.114.34', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1hqd074dezrsd5zd6cc3mm0vh88pmg8nsf6lu7g/balance
# https://mixnet.api.explorers.guru/api/mixnodes/73/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/73/uptime
# https://185.215.167.12:8000/stats
# HTTPSConnectionPool(host='185.215.167.12', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1k7aymy72003ty5s9ka0rf5zrx9d4l84tfk0fd8/balance
# https://mixnet.api.explorers.guru/api/mixnodes/75/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/75/uptime
# https://173.249.36.4:8000/stats
# HTTPSConnectionPool(host='173.249.36.4', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n123z6e9eqs9pr52anwz6dclml70fa737s7udhvn/balance
# https://mixnet.api.explorers.guru/api/mixnodes/77/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/77/uptime
# https://65.108.248.53:8000/stats
# HTTPSConnectionPool(host='65.108.248.53', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n169ruu8y9rnfvh8djg6m39s43mupe7fqyyztl5y/balance
# https://mixnet.api.explorers.guru/api/mixnodes/81/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/81/uptime
# https://167.235.242.140:8000/stats
# HTTPSConnectionPool(host='167.235.242.140', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n14h0dupvvv4ufx04949a9u8vqxmwj9vxa2qtglc/balance
# https://mixnet.api.explorers.guru/api/mixnodes/82/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/82/uptime
# https://nym.stavr.tech:8000/stats
# HTTPSConnectionPool(host='nym.stavr.tech', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1tpjnyxjupjd0vmf7j4yrgqtewrgps7h9mx0mam/balance
# https://mixnet.api.explorers.guru/api/mixnodes/83/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/83/uptime
# https://5.161.105.116:8000/stats
# HTTPSConnectionPool(host='5.161.105.116', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1a3sufm9sus9vrhr3n4ufcv6aurc3jzp35p64ch/balance
# https://mixnet.api.explorers.guru/api/mixnodes/84/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/84/uptime
# https://167.235.134.255:8000/stats
# HTTPSConnectionPool(host='167.235.134.255', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n17kkldwe0a74gc2hvyunx30rw9k4xgyh85f6rqt/balance
# https://mixnet.api.explorers.guru/api/mixnodes/87/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/87/uptime
# https://65.21.105.117:8000/stats
# HTTPSConnectionPool(host='65.21.105.117', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1s0x9ztxs7x2ylqsnws8y5qnerwc5yljmcqcsyl/balance
# https://mixnet.api.explorers.guru/api/mixnodes/92/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/92/uptime
# https://95.216.210.35:8000/stats
# HTTPSConnectionPool(host='95.216.210.35', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1gvsp2e25aj5yvy5ufcadf55yezw35ghwsv6a6w/balance
# https://mixnet.api.explorers.guru/api/mixnodes/93/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/93/uptime
# https://178.79.173.113:8000/stats
# HTTPSConnectionPool(host='178.79.173.113', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1szc8y07wrdu902wrd5jpqcelk7s0dvmm7et08l/balance
# https://mixnet.api.explorers.guru/api/mixnodes/97/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/97/uptime
# https://manekineko.internet-box.ch:8000/stats
# HTTPSConnectionPool(host='manekineko.internet-box.ch', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1fjcp5pzzzhgzg4278r8r68jcffzn780nesf8m0/balance
# https://mixnet.api.explorers.guru/api/mixnodes/99/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/99/uptime
# https://38.54.4.21:8000/stats
# HTTPSConnectionPool(host='38.54.4.21', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1antyfjrzk2xq3gj8vnpas8qzlwfkwklxen7e6w/balance
# https://mixnet.api.explorers.guru/api/mixnodes/100/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/100/uptime
# https://45.11.27.209:8000/stats
# HTTPSConnectionPool(host='45.11.27.209', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1n8x0g6vjqlmh22csn954pe8uhkaxn5j49gema5/balance
# https://mixnet.api.explorers.guru/api/mixnodes/101/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/101/uptime
# https://165.22.67.203:8000/stats
# HTTPSConnectionPool(host='165.22.67.203', port=8000): Max retries exceeded with url: /stats (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x28b8a6f40>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1m57y76hxydgdmpec4s78yrrn5qezlddq2jtec4/balance
# https://mixnet.api.explorers.guru/api/mixnodes/102/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/102/uptime
# https://yavallego.ddns.net:8000/stats
# HTTPSConnectionPool(host='yavallego.ddns.net', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1v3w8knxcpyqtkmt85x0zwscy6gfmwhm25ep2qh/balance
# https://mixnet.api.explorers.guru/api/mixnodes/106/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/106/uptime
# https://185.229.90.228:8000/stats
# HTTPSConnectionPool(host='185.229.90.228', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1gp957czryfgyvxwn3tfnyy2f0t9g2p4phf6v43/balance
# https://mixnet.api.explorers.guru/api/mixnodes/108/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/108/uptime
# https://148.251.13.186:8000/stats
# HTTPSConnectionPool(host='148.251.13.186', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1mmd25hzgqdh42ngtyhgtzkjxf7kshsdz7zz3l4/balance
# https://mixnet.api.explorers.guru/api/mixnodes/109/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/109/uptime
# https://185.204.3.178:8000/stats
# HTTPSConnectionPool(host='185.204.3.178', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1wckhaac8zwtegvesaq8p3x4j5hcp0vx5sx3k4m/balance
# https://mixnet.api.explorers.guru/api/mixnodes/111/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/111/uptime
# https://139.180.156.150:8000/stats
# HTTPSConnectionPool(host='139.180.156.150', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n16g7rmc9yp2cy2x3jj2tyd02450dytcppfvt9e0/balance
# https://mixnet.api.explorers.guru/api/mixnodes/112/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/112/uptime
# https://3.145.72.33:8000/stats
# HTTPSConnectionPool(host='3.145.72.33', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n147ys02zr0p0c9j784slunjhg4sag4frvc8gr53/balance
# https://mixnet.api.explorers.guru/api/mixnodes/117/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/117/uptime
# https://89.58.16.140:8000/stats
# HTTPSConnectionPool(host='89.58.16.140', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1vs7aplr9n208artds98j2h7mdpyhlrq4kj6k67/balance
# https://mixnet.api.explorers.guru/api/mixnodes/119/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/119/uptime
# https://162.55.47.132:8000/stats
# HTTPSConnectionPool(host='162.55.47.132', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1xh2yhdy4xkmd56pr0e7ejf7d7wu8yrnpvv3rl6/balance
# https://mixnet.api.explorers.guru/api/mixnodes/121/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/121/uptime
# https://65.108.57.170:8000/stats
# HTTPSConnectionPool(host='65.108.57.170', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1hffgqc7r4f9xej5g6s7g5ajywysltzk7rnnzre/balance
# https://mixnet.api.explorers.guru/api/mixnodes/124/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/124/uptime
# https://85.239.40.63:8000/stats
# HTTPSConnectionPool(host='85.239.40.63', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1sxsyfsj03r0rwy3mpcwyqhh4rttyrlpy88249q/balance
# https://mixnet.api.explorers.guru/api/mixnodes/125/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/125/uptime
# https://5.161.65.203:8000/stats
# HTTPSConnectionPool(host='5.161.65.203', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n13sq83cthtap3mxacf4lud0lu9mv55n5mkxphu3/balance
# https://mixnet.api.explorers.guru/api/mixnodes/129/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/129/uptime
# https://80.93.19.69:8000/stats
# HTTPSConnectionPool(host='80.93.19.69', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1lwwjp67rc2acjhnete7vdm9shpphgsme5er3c8/balance
# https://mixnet.api.explorers.guru/api/mixnodes/131/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/131/uptime
# https://88.208.121.78:8000/stats
# HTTPSConnectionPool(host='88.208.121.78', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLZeroReturnError(6, 'TLS/SSL connection has been closed (EOF) (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1h7a3l2x6mnzv3veg586ewsfhu096m69gyzchcp/balance
# https://mixnet.api.explorers.guru/api/mixnodes/132/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/132/uptime
# https://159.69.0.106:8000/stats
# HTTPSConnectionPool(host='159.69.0.106', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1ac2x30n0q2c8lxu6tyzrkkq84l3pa5tkh55gjx/balance
# https://mixnet.api.explorers.guru/api/mixnodes/133/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/133/uptime
# https://194.233.69.21:8000/stats
# HTTPSConnectionPool(host='194.233.69.21', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1xmwdsuff3ddcc5j92kwhrs3dquzyt5stmp420v/balance
# https://mixnet.api.explorers.guru/api/mixnodes/134/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/134/uptime
# https://135.181.196.140:8000/stats
# HTTPSConnectionPool(host='135.181.196.140', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1hz36qnmnhztm59n74q8sjgffn690fmltgajtkz/balance
# https://mixnet.api.explorers.guru/api/mixnodes/136/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/136/uptime
# https://103.50.32.118:8000/stats
# HTTPSConnectionPool(host='103.50.32.118', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n185ht430m956r5vayxll56umqxrq90w7xf89wkq/balance
# https://mixnet.api.explorers.guru/api/mixnodes/137/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/137/uptime
# https://65.108.72.253:8000/stats
# HTTPSConnectionPool(host='65.108.72.253', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1njc47hrj6m2dvjnnw7qnv436m7qvchu60z8z0g/balance
# https://mixnet.api.explorers.guru/api/mixnodes/139/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/139/uptime
# https://138.68.180.39:8000/stats
# HTTPSConnectionPool(host='138.68.180.39', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1depxyx74f2nqeld0evre0jgcgtuxlx8lfmt4ee/balance
# https://mixnet.api.explorers.guru/api/mixnodes/140/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/140/uptime
# https://95.216.164.87:8000/stats
# HTTPSConnectionPool(host='95.216.164.87', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1yhc9skp7xp8j9kzqfjssglryqxxd25kjqu28t8/balance
# https://mixnet.api.explorers.guru/api/mixnodes/141/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/141/uptime
# https://167.235.78.74:8000/stats
# HTTPSConnectionPool(host='167.235.78.74', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1m9tkc0h6w5e4zkaaaupq3emecnz5fczfswmpvx/balance
# https://mixnet.api.explorers.guru/api/mixnodes/144/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/144/uptime
# https://65.108.205.246:8000/stats
# HTTPSConnectionPool(host='65.108.205.246', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1t8ya84jt48trgrwm0se3shjxnkup0wtf7402z7/balance
# https://mixnet.api.explorers.guru/api/mixnodes/145/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/145/uptime
# https://95.216.141.214:8000/stats
# HTTPSConnectionPool(host='95.216.141.214', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n15vjknrrquc2wfd02ghlz3g3pz93q4kka0tp3eg/balance
# https://mixnet.api.explorers.guru/api/mixnodes/147/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/147/uptime
# https://49.12.68.22:8000/stats
# HTTPSConnectionPool(host='49.12.68.22', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1dsdzqn0knxlyv3v59u665lgr5uvd44kzh3laud/balance
# https://mixnet.api.explorers.guru/api/mixnodes/148/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/148/uptime
# https://195.201.174.171:8000/stats
# HTTPSConnectionPool(host='195.201.174.171', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1sfjmku8349jm9sqmc79qegk6h9wptf8el0t469/balance
# https://mixnet.api.explorers.guru/api/mixnodes/152/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/152/uptime
# https://77.241.194.41:8000/stats
# HTTPSConnectionPool(host='77.241.194.41', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n12al9huxzle5hx3cgw93tfmxt80l3qz47c3czuu/balance
# https://mixnet.api.explorers.guru/api/mixnodes/153/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/153/uptime
# https://51.68.47.21:8000/stats
# HTTPSConnectionPool(host='51.68.47.21', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n17g8p4xejhde6gnfa209th5w7gv6ah9vmtc7ks5/balance
# https://mixnet.api.explorers.guru/api/mixnodes/156/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/156/uptime
# https://77.241.194.36:8000/stats
# HTTPSConnectionPool(host='77.241.194.36', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1hhqpwhz7m0lscg0lwlmvl0k7tvl0jny388yet3/balance
# https://mixnet.api.explorers.guru/api/mixnodes/161/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/161/uptime
# https://116.203.80.113:8000/stats
# HTTPSConnectionPool(host='116.203.80.113', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n17l85km8233y070vaq2vywfrflqmqyv5as9hjut/balance
# https://mixnet.api.explorers.guru/api/mixnodes/163/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/163/uptime
# https://188.34.196.131:8000/stats
# HTTPSConnectionPool(host='188.34.196.131', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1hjlmkzgjjah6wczhsllnwpf3qdma4zqj6kg6gu/balance
# https://mixnet.api.explorers.guru/api/mixnodes/164/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/164/uptime
# https://45.153.230.188:8000/stats
# HTTPSConnectionPool(host='45.153.230.188', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1mu7906a9z8ttwssvq4h5pgmxzwzyvgne8vu9uf/balance
# https://mixnet.api.explorers.guru/api/mixnodes/167/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/167/uptime
# https://190.10.8.118:8000/stats
# HTTPSConnectionPool(host='190.10.8.118', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n14qffmg2vh8d8xgvs29xjyw3ghtu3u5d6s8jwtw/balance
# https://mixnet.api.explorers.guru/api/mixnodes/169/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/169/uptime
# https://178.62.227.112:8000/stats
# HTTPSConnectionPool(host='178.62.227.112', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1a7zsxuw0v5pgd7r4v3rpyj0030t30fnx88shct/balance
# https://mixnet.api.explorers.guru/api/mixnodes/170/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/170/uptime
# https://nym.cyberomanov.tech:8000/stats
# HTTPSConnectionPool(host='nym.cyberomanov.tech', port=8000): Max retries exceeded with url: /stats (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x28b972cd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1fa47n6rn2cqnft05lxll909tel83czqsedxdue/balance
# https://mixnet.api.explorers.guru/api/mixnodes/171/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/171/uptime
# https://62.171.148.161:8000/stats
# HTTPSConnectionPool(host='62.171.148.161', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1y7fmnh9z0rmv9vsc6trwz5p22m92gzuj7alcmq/balance
# https://mixnet.api.explorers.guru/api/mixnodes/172/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/172/uptime
# https://216.238.82.150:8000/stats
# HTTPSConnectionPool(host='216.238.82.150', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1qclqml4rykcac2lp6nyvyezqajvsrcs0tfjaym/balance
# https://mixnet.api.explorers.guru/api/mixnodes/175/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/175/uptime
# https://95.214.53.18:8000/stats
# ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1rrma7t65cz87yez7dkgv7j923u25yespwafm06/balance
# https://mixnet.api.explorers.guru/api/mixnodes/176/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/176/uptime
# https://212.83.179.55:8000/stats
# HTTPSConnectionPool(host='212.83.179.55', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1ujapaxvg0z26th4kpqrakdjzm5g0fh6a0hysv8/balance
# https://mixnet.api.explorers.guru/api/mixnodes/177/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/177/uptime
# https://116.203.212.252:8000/stats
# HTTPSConnectionPool(host='116.203.212.252', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1hlw9guf67f6h0xyt9w8selanz32j59jqe8fe0n/balance
# https://mixnet.api.explorers.guru/api/mixnodes/178/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/178/uptime
# https://185.19.28.137:8000/stats
# HTTPSConnectionPool(host='185.19.28.137', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1ern0pt7wyz4vrhuhas5nawn3xxegeny7rar34l/balance
# https://mixnet.api.explorers.guru/api/mixnodes/180/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/180/uptime
# https://207.244.234.242:8000/stats
# HTTPSConnectionPool(host='207.244.234.242', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1m86709jhxvlvff3xs7hzzvkv9r7htnqx0cnjjr/balance
# https://mixnet.api.explorers.guru/api/mixnodes/184/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/184/uptime
# https://159.100.245.86:8000/stats
# HTTPSConnectionPool(host='159.100.245.86', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1a7kspc26cznk93ejzsd6eh24spx64yu38ghtsj/balance
# https://mixnet.api.explorers.guru/api/mixnodes/185/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/185/uptime
# https://77.241.194.124:8000/stats
# HTTPSConnectionPool(host='77.241.194.124', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n16j0q873qvp25kqamxjzr73aumyyk7ff6qjw789/balance
# https://mixnet.api.explorers.guru/api/mixnodes/187/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/187/uptime
# https://65.108.61.38:8000/stats
# HTTPSConnectionPool(host='65.108.61.38', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1g7sxrkktrppsnlknjt05una2r0ae4m84aup377/balance
# https://mixnet.api.explorers.guru/api/mixnodes/188/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/188/uptime
# https://195.2.84.181:8000/stats
# HTTPSConnectionPool(host='195.2.84.181', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1dpn04j8m0swjlmmktxqg5y2npfsenfad287hsw/balance
# https://mixnet.api.explorers.guru/api/mixnodes/190/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/190/uptime
# https://174.138.22.190:8000/stats
# HTTPSConnectionPool(host='174.138.22.190', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1jn0jej3v56eezsn80dca02aav8nev4r3v8nxzd/balance
# https://mixnet.api.explorers.guru/api/mixnodes/192/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/192/uptime
# https://212.118.52.117:8000/stats
# HTTPSConnectionPool(host='212.118.52.117', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1d3s3a3yda7fdy8r4p3u855u5vdajvwpnlexzsv/balance
# https://mixnet.api.explorers.guru/api/mixnodes/193/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/193/uptime
# https://142.132.184.207:8000/stats
# HTTPSConnectionPool(host='142.132.184.207', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1lh9dhpwvh4cd5z0fv65jstdl6cmwmvu3xk8ap3/balance
# https://mixnet.api.explorers.guru/api/mixnodes/194/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/194/uptime
# https://45.77.224.148:8000/stats
# HTTPSConnectionPool(host='45.77.224.148', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1ug0mkrflx0u8u8hjqsu442crkz852xgfw5hnqr/balance
# https://mixnet.api.explorers.guru/api/mixnodes/195/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/195/uptime
# https://188.119.112.178:8000/stats
# HTTPSConnectionPool(host='188.119.112.178', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1vnxqh7kvrl7tfp872rklzywaavdqgrzgm00dhw/balance
# https://mixnet.api.explorers.guru/api/mixnodes/196/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/196/uptime
# https://45.87.154.145:8000/stats
# HTTPSConnectionPool(host='45.87.154.145', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1evkdd5xfadchj97j058wggfcnr907zkl36knvf/balance
# https://mixnet.api.explorers.guru/api/mixnodes/197/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/197/uptime
# https://77.241.194.58:8000/stats
# HTTPSConnectionPool(host='77.241.194.58', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1vvdwvezwysrazvnv08fhqaag7g7uy62eec9pgl/balance
# https://mixnet.api.explorers.guru/api/mixnodes/202/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/202/uptime
# https://23.92.28.117:8000/stats
# HTTPSConnectionPool(host='23.92.28.117', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1506rgwzm85tszvc558r0zwr8lssgaxak2vgdtz/balance
# https://mixnet.api.explorers.guru/api/mixnodes/207/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/207/uptime
# https://195.201.218.127:8000/stats
# ...
# https://216.238.81.160:8000/stats
# HTTPSConnectionPool(host='216.238.81.160', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n17u36v5tshdn7ujn3aluua044dux6vkqkjla38t/balance
# https://mixnet.api.explorers.guru/api/mixnodes/935/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/935/uptime
# https://188.190.246.251:8000/stats
# HTTPSConnectionPool(host='188.190.246.251', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1ztsvusgzsr2ztrwrwekaq9mmv0fpd2g5hds5ja/balance
# https://mixnet.api.explorers.guru/api/mixnodes/936/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/936/uptime
# https://143.202.162.168:8000/stats
# HTTPSConnectionPool(host='143.202.162.168', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n13nzmmpujhlchezgwy7m5l2qw7cvjj26qdak5lr/balance
# https://mixnet.api.explorers.guru/api/mixnodes/937/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/937/uptime
# https://217.61.57.11:8000/stats
# HTTPSConnectionPool(host='217.61.57.11', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1885qn8as4d00v0x3w5mlkwjmylgve3cjvneuj5/balance
# https://mixnet.api.explorers.guru/api/mixnodes/938/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/938/uptime
# https://216.238.68.174:8000/stats
# HTTPSConnectionPool(host='216.238.68.174', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1seeak3u03vv37elq92m25e3uegy96xggjtvttm/balance
# https://mixnet.api.explorers.guru/api/mixnodes/939/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/939/uptime
# https://216.238.83.124:8000/stats
# HTTPSConnectionPool(host='216.238.83.124', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1se6sjjkcpvku8z4m0hvfv8023rdmc7aranl7ja/balance
# https://mixnet.api.explorers.guru/api/mixnodes/942/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/942/uptime
# https://148.113.1.150:8000/stats
# HTTPSConnectionPool(host='148.113.1.150', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1z2sm5099vuul6ujueths3rc4skx7c69r9zq6zx/balance
# https://mixnet.api.explorers.guru/api/mixnodes/946/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/946/uptime
# https://193.34.213.6:8000/stats
# HTTPSConnectionPool(host='193.34.213.6', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n16te0gwxctcldjr5rtsqjennjl4gqkvkgx9su0n/balance
# https://mixnet.api.explorers.guru/api/mixnodes/948/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/948/uptime
# https://45.86.65.186:8000/stats
# HTTPSConnectionPool(host='45.86.65.186', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1qg6a65p4ush2mt4dpwhzju5u4jktxx0sp0zfcv/balance
# https://mixnet.api.explorers.guru/api/mixnodes/949/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/949/uptime
# https://149.202.44.152:8000/stats
# HTTPSConnectionPool(host='149.202.44.152', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1wzzd4hpjur0la2fl332mw3nwkvc7ggugywfv9v/balance
# https://mixnet.api.explorers.guru/api/mixnodes/951/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/951/uptime
# https://77.91.75.131:8000/stats
# HTTPSConnectionPool(host='77.91.75.131', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1e2lru0jnzmclqjpp27uqdy8zx0q7lynmyjvxyl/balance
# https://mixnet.api.explorers.guru/api/mixnodes/952/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/952/uptime
# https://190.120.231.64:8000/stats
# HTTPSConnectionPool(host='190.120.231.64', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1qcgswwchk0z8ggylrsf5zld85dmmp2fark8y6v/balance
# https://mixnet.api.explorers.guru/api/mixnodes/953/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/953/uptime
# https://200.45.208.36:8000/stats
# HTTPSConnectionPool(host='200.45.208.36', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n106jvmzx06srdcm9gr9uahjxd0yh4ds78wmk2um/balance
# https://mixnet.api.explorers.guru/api/mixnodes/956/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/956/uptime
# https://216.238.71.82:8000/stats
# HTTPSConnectionPool(host='216.238.71.82', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1rg4ursf45afhxqmmyh2rzv0720y38x6pus4qgs/balance
# https://mixnet.api.explorers.guru/api/mixnodes/959/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/959/uptime
# https://212.227.153.133:8000/stats
# HTTPSConnectionPool(host='212.227.153.133', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n19hersavprsv655m67h34n5ccd9gk4kngxy9rak/balance
# https://mixnet.api.explorers.guru/api/mixnodes/961/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/961/uptime
# https://185.47.254.205:8000/stats
# HTTPSConnectionPool(host='185.47.254.205', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1qd8qqshnzz767pwsp7ferzrtyj9vzlzq2qzr5z/balance
# https://mixnet.api.explorers.guru/api/mixnodes/966/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/966/uptime
# https://149.102.140.181:8000/stats
# HTTPSConnectionPool(host='149.102.140.181', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n127rmr6y2xaapmwydskw2mkaet7gms0m8ng3uzp/balance
# https://mixnet.api.explorers.guru/api/mixnodes/967/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/967/uptime
# https://103.175.217.153:8000/stats
# HTTPSConnectionPool(host='103.175.217.153', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1n5crffd0202stwcsjus8fjmzmtqc0ml5tphemg/balance
# https://mixnet.api.explorers.guru/api/mixnodes/968/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/968/uptime
# https://190.10.8.114:8000/stats
# HTTPSConnectionPool(host='190.10.8.114', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n135zgk2t7an84l0ch7tmyce3syczhqujr4gwnlj/balance
# https://mixnet.api.explorers.guru/api/mixnodes/971/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/971/uptime
# https://173.249.59.172:8000/stats
# HTTPSConnectionPool(host='173.249.59.172', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1w7j8nt6deg2kpxuql8u28jxxzzww74yrh8zhh2/balance
# https://mixnet.api.explorers.guru/api/mixnodes/973/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/973/uptime
# https://194.233.73.148:8000/stats
# HTTPSConnectionPool(host='194.233.73.148', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1wkl4kzzv7hfeug3kl6uyukaf6hwjzf0s2hmz4j/balance
# https://mixnet.api.explorers.guru/api/mixnodes/975/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/975/uptime
# https://164.90.180.76:8000/stats
# HTTPSConnectionPool(host='164.90.180.76', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n18lv3ux8ejkvksn654xtk2vd03eyuc0agllwsg5/balance
# https://mixnet.api.explorers.guru/api/mixnodes/976/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/976/uptime
# https://45.77.55.210:8000/stats
# HTTPSConnectionPool(host='45.77.55.210', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1kq2fk5knu7yt8p93ega0ez65vu33pr2jvjmgcq/balance
# https://mixnet.api.explorers.guru/api/mixnodes/977/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/977/uptime
# https://65.109.89.235:8000/stats
# HTTPSConnectionPool(host='65.109.89.235', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1thh4lp9prlxejj3asee50rc6azft4m9rpfjx7l/balance
# https://mixnet.api.explorers.guru/api/mixnodes/978/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/978/uptime
# https://37.120.245.102:8000/stats
# HTTPSConnectionPool(host='37.120.245.102', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n13l9hlen6ln7gjwmq53whngn9wa366qfs4fs8u5/balance
# https://mixnet.api.explorers.guru/api/mixnodes/979/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/979/uptime
# https://41.76.110.26:8000/stats
# HTTPSConnectionPool(host='41.76.110.26', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1hmxfppqyqw0kvctdse2ua83mxu6pf5t3kpseq2/balance
# https://mixnet.api.explorers.guru/api/mixnodes/980/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/980/uptime
# https://167.179.90.210:8000/stats
# HTTPSConnectionPool(host='167.179.90.210', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1nvv3x3dql64lxsf8ujqp0fawvmycszutfk4gw8/balance
# https://mixnet.api.explorers.guru/api/mixnodes/981/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/981/uptime
# https://139.84.171.148:8000/stats
# HTTPSConnectionPool(host='139.84.171.148', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1msdq7q65chr2arndnedt3739qrfz92fpxc2qnz/balance
# https://mixnet.api.explorers.guru/api/mixnodes/984/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/984/uptime
# https://89.147.110.239:8000/stats
# HTTPSConnectionPool(host='89.147.110.239', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1449kvy3rg760ufvxjn3jef4njyzy4nxmdx8y34/balance
# https://mixnet.api.explorers.guru/api/mixnodes/985/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/985/uptime
# https://51.38.235.143:8000/stats
# HTTPSConnectionPool(host='51.38.235.143', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1aakl800zg5w65hcwfk0j5a9ndq53lauzw6ng58/balance
# https://mixnet.api.explorers.guru/api/mixnodes/986/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/986/uptime
# https://15.235.140.70:8000/stats
# HTTPSConnectionPool(host='15.235.140.70', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1m6fswhet2ascksageq0yqyt9x3d0t7hcu95929/balance
# https://mixnet.api.explorers.guru/api/mixnodes/987/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/987/uptime
# https://89.117.55.138:8000/stats
# HTTPSConnectionPool(host='89.117.55.138', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1zar3ankmyr0wgyrueve24xryfz285ehpmnm8q6/balance
# https://mixnet.api.explorers.guru/api/mixnodes/990/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/990/uptime
# https://195.15.254.68:8000/stats
# HTTPSConnectionPool(host='195.15.254.68', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n10amq96xgpjeppa95rj0gtffgk7jr20l5cxfhjn/balance
# https://mixnet.api.explorers.guru/api/mixnodes/991/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/991/uptime
# https://195.15.253.22:8000/stats
# HTTPSConnectionPool(host='195.15.253.22', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1d86p63vkjdnm2k4td248xddd7z5h2nlgfua239/balance
# https://mixnet.api.explorers.guru/api/mixnodes/992/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/992/uptime
# https://77.123.155.53:8000/stats
# HTTPSConnectionPool(host='77.123.155.53', port=8000): Max retries exceeded with url: /stats (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1131)')))
# None
# https://mixnet.api.explorers.guru/api/accounts/n1yc8smp2at7zdfjs6cmz9qa3eyxrhk2alxyufuz/balance
# https://mixnet.api.explorers.guru/api/mixnodes/994/estimated_reward
# https://mixnet.api.explorers.guru/api/mixnodes/994/uptime
# https://51.38.230.101:8000/stats
# ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# None

# %%
df_nodes=df_nodes.drop(columns=['selfBonded'])
df_nodes['hours_since_last_touched']=[float((datetime.now()-df_nodes.iloc[i].last_touched).days)/24 for i in range(0,len(df_nodes))]
df_nodes['stake_till_saturation']=(df_nodes.current_bond+df_nodes.delegate_stake)*(1/(df_nodes.saturation/100)-1)
df_nodes.loc[df_nodes['stake_till_saturation']<0,'stake_till_saturation']=0
df_nodes['delegate_reward_per_k_nym']=0
df_nodes.loc[df_nodes.total_node_reward_estimate-df_nodes.cost_hour>0, 'delegate_reward_per_k_nym']=(1-df_nodes.profit_margin)*1000/(df_nodes.current_bond+df_nodes.delegate_stake)*(df_nodes.total_node_reward_estimate-df_nodes.cost_hour)
df_nodes['delegate_reward_per_k_nym_check']=df_nodes.delegates_estimate/df_nodes.delegate_stake*1000
df_nodes['rank_delegate_reward']=df_nodes.delegate_reward_per_k_nym.rank(ascending=False)

# %%
date_str = '2023-06-19'
df_nodes.to_pickle('nym_nodes_' + date_str + '.pkl')
df_nodes.to_csv('node_data_' + date_str + '.csv')

# %%
df_nodes
# Out:
#       id                                     owner  rank    status  verify  \
# 0      1  n1cg6lgel27zmq8yutxgnu2tdzx3hf0m8uemfpwp   168  inactive   False
# 1      2  n1vfdtzh9vzaaxxv9n9w4ywdzle9m2pejhx0d5r7   135    active   False
# 2      5  n1v7nrjw6pnkrdxmmuk7pjtxrzrxrtztgh33pszu     1    active   False
# 3      6  n1kal4zg6d4xe8a9uygz4vh3ngyqgpjud53m0n9w   173    active   False
# 4      8  n1hn0fkhequgwdxw3d600jhax76j07kqdxklvcwn   167    active   False
# ..   ...                                       ...   ...       ...     ...
# 462  987  n1m6fswhet2ascksageq0yqyt9x3d0t7hcu95929    48  inactive   False
# 463  990  n1zar3ankmyr0wgyrueve24xryfz285ehpmnm8q6   251  inactive   False
# 464  991  n10amq96xgpjeppa95rj0gtffgk7jr20l5cxfhjn   252  inactive   False
# 465  992  n1d86p63vkjdnm2k4td248xddd7z5h2nlgfua239   220  inactive   False
# 466  994  n1yc8smp2at7zdfjs6cmz9qa3eyxrhk2alxyufuz   272  inactive   False
#
#      warning                                warning_description  saturation  \
# 0      False                                                       0.242759
# 1       True  This node has been impersonating Nodes.Guru an...   68.529426
# 2      False                                                     164.088609
# 3      False                                                      23.002355
# 4      False                                                      25.583037
# ..       ...                                                ...         ...
# 462    False                                                       3.833045
# 463    False                                                       0.027735
# 464    False                                                       0.027735
# 465    False                                                       0.106262
# 466    False                                                       0.015939
#
#      current_bond        last_touched  ...  delegatedLiquid    claimable  \
# 0      182.267768 2023-06-19 09:01:15  ...         0.000000    19.099283
# 1     2844.316263 2023-06-19 09:01:15  ...         0.000000  1152.359851
# 2    35750.106604 2023-06-19 09:01:15  ...         0.000000  6997.703159
# 3     5048.117226 2023-06-19 09:01:15  ...         0.000000    44.117253
# 4     2506.664010 2023-06-19 09:01:15  ...      6297.209846   221.131821
# ..            ...                 ...  ...              ...          ...
# 462  36071.618974 2023-06-19 09:01:15  ...         0.000000    21.618974
# 463    261.005704 2023-06-19 09:01:15  ...         0.000000     0.005704
# 464    261.005589 2023-06-19 09:01:15  ...         0.000000     0.005589
# 465   1000.000000 2023-06-19 09:01:15  ...         0.000000     0.000000
# 466    150.000000 2023-06-19 09:01:15  ...         0.000000     0.000000
#
#      claimableCommission claimableRewards claimableUnlocked  \
# 0              18.081553         1.017730               0.0
# 1            1152.359851         0.000000               0.0
# 2            6997.703159         0.000000               0.0
# 3              44.117253         0.000000               0.0
# 4             141.800527        79.331293               0.0
# ..                   ...              ...               ...
# 462            21.618974         0.000000               0.0
# 463             0.005704         0.000000               0.0
# 464             0.005589         0.000000               0.0
# 465             0.000000         0.000000               0.0
# 466             0.000000         0.000000               0.0
#
#     hours_since_last_touched stake_till_saturation delegate_reward_per_k_nym  \
# 0                        0.0         938784.962780                  0.000000
# 1                        0.0         296159.970870                  0.017811
# 2                        0.0              0.000000                  0.012764
# 3                        0.0         724601.347529                  0.019921
# 4                        0.0         700315.330626                  0.020566
# ..                       ...                   ...                       ...
# 462                      0.0         904997.870374                  0.000000
# 463                      0.0         940808.483643                  0.000000
# 464                      0.0         940808.483759                  0.000000
# 465                      0.0         940069.489348                  0.000000
# 466                      0.0         940919.489348                  0.000000
#
#      delegate_reward_per_k_nym_check  rank_delegate_reward
# 0                           0.000000                 354.0
# 1                           0.017768                 218.0
# 2                           0.012763                 239.0
# 3                           0.019918                 141.0
# 4                           0.020561                  79.0
# ..                               ...                   ...
# 462                              NaN                 354.0
# 463                              NaN                 354.0
# 464                              NaN                 354.0
# 465                              NaN                 354.0
# 466                              NaN                 354.0
#
# [467 rows x 50 columns]
